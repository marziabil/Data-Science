# %% [markdown]
# ## Task C: Probability

# %%
from numpy import random
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

sns.histplot(random.poisson(lam=50, size=1000), kde=False) #lam is 50 since it is the average of the call count

plt.show()

# %%
callCenter = pd.read_csv('CallCounts.csv') #read CSV file
callCenter.hist(column='CallCountsPerHour') #compare the graph with the above one
# Out:
# array([[<AxesSubplot:title={'center':'CallCountsPerHour'}>]], dtype=object)

# %% [markdown]
# #### Fit a named statistical distribution to the data (e.g. Gaussian, Beta etc.). Clearly state any assumptions made and justify your choice of distribution logically.
#
# This is a Poission distrubution.
#
# Reasons for selecting a Poisson distribution:
# - A Poisson distribution is used to show how many times an event is likely to happen over a given period of time. In this case the count of calls is recorded over a year.
# - Essentially it's a count distribution.
#
# To verify the above, the following steps were taken:
# - A histogram for random numbers using the possion distribution was created
# - In the first graph, lam was set to 50 since it is the average of call counts
# - Another histogram was created with the dataset
# - A comparison of the two graphs shows similar distributions
